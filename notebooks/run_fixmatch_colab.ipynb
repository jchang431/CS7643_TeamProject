# %%
from getpass import getpass
token = getpass("GitHub token: ")

# !git clone https://jchang431:{token}@github.com/jchang431/CS7643_TeamProject.git
# %cd /content/CS7643_TeamProject
# !ls
# Out:
# GitHub token: ··········
# Cloning into 'CS7643_TeamProject'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 25 (delta 2), reused 19 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 10.48 KiB | 10.48 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/CS7643_TeamProject
# configs  README.md  requirements.txt  src
