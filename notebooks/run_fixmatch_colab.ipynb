# %%
# !git clone https://github.com/jchang431/CS7643_TeamProject.git
# Out:
# Cloning into 'CS7643_TeamProject'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 62 (delta 21), reused 21 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 29.56 KiB | 9.85 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd /content/CS7643_TeamProject
# !ls
# Out:
# /content/CS7643_TeamProject
# configs  notebooks  README.md  requirements.txt  src

# %%
# !pip install -r requirements.txt

# %%
# !git config --global --list
# Out:
# user.name=jchang431
# user.email=jchang431@gatech.edu

# %%
# !git log --oneline -1
# Out:
# 352bc5c (HEAD -> main) Add CTAugment support and update FixMatch pipeline

# %%
# !git remote -v
# Out:
# origin	https://github.com/jchang431/CS7643_TeamProject.git (fetch)
# origin	https://github.com/jchang431/CS7643_TeamProject.git (push)

# %%
# !git add .
# !git commit -m "Update project files"
# Out:
# [main 3f36f72] Update project files
#  2 files changed, 29 insertions(+), 11 deletions(-)

# %%
# !git pull origin main --rebase
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 7.32 KiB | 2.44 MiB/s, done.
# From https://github.com/jchang431/CS7643_TeamProject
#  * branch            main       -> FETCH_HEAD
#    8ae0de1..7ed6a2a  main       -> origin/main
# Successfully rebased and updated refs/heads/main.

# %%
# !git config --global user.name "jchang431"
# !git config --global user.email "jchang431@gatech.edu"

# %%
from getpass import getpass
token = getpass("GitHub PAT: ")
# Out:
# GitHub PAT: ··········

# %%
# !git remote set-url origin https://jchang431:{token}@github.com/jchang431/CS7643_TeamProject.git
# !git push origin main
# !git remote set-url origin https://github.com/jchang431/CS7643_TeamProject.git
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 1.20 KiB | 1.20 MiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/jchang431/CS7643_TeamProject.git
#    7ed6a2a..5ca972c  main -> main

# %%
# !python -m src.train
# Out:
# Using device: cuda
# # labeled batches: 3
# # unlabeled batches: 111
# [Epoch 001/300] lr=0.03000 loss=1.3408 xe=1.3337 xeu=0.0071 mask=0.0079 test_acc=9.90
# [Epoch 002/300] lr=0.03000 loss=0.5188 xe=0.3921 xeu=0.1267 mask=0.1254 test_acc=11.01
# [Epoch 003/300] lr=0.03000 loss=0.3739 xe=0.1345 xeu=0.2394 mask=0.2506 test_acc=14.05
# [Epoch 004/300] lr=0.02999 loss=0.3503 xe=0.0790 xeu=0.2712 mask=0.3044 test_acc=17.28
# [Epoch 005/300] lr=0.02999 loss=0.3214 xe=0.0504 xeu=0.2710 mask=0.3354 test_acc=20.13
# [Epoch 006/300] lr=0.02999 loss=0.3266 xe=0.0573 xeu=0.2693 mask=0.3445 test_acc=23.15
# [Epoch 007/300] lr=0.02998 loss=0.2944 xe=0.0281 xeu=0.2664 mask=0.3823 test_acc=26.28
# [Epoch 008/300] lr=0.02998 loss=0.3101 xe=0.0319 xeu=0.2782 mask=0.3980 test_acc=28.99
# [Epoch 009/300] lr=0.02997 loss=0.3112 xe=0.0353 xeu=0.2759 mask=0.3977 test_acc=31.66
# [Epoch 010/300] lr=0.02997 loss=0.3004 xe=0.0328 xeu=0.2677 mask=0.4043 test_acc=34.36
# ...
